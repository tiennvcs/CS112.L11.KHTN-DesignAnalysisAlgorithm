# %% [markdown]
# <a href="https://colab.research.google.com/github/tiennvuit/CS112.L11.KHTN/blob/master/Assignment_05/KhoaSo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center> BÀI TẬP TUẦN 5 (08-10-2020)</CENTER></h1>

# %% [markdown]
# ## Thông tin nhóm:
#
# 1. Trần Trung Anh   - 18520473
# 2. Nguyễn Phú Quốc  - 18520343
# 3. Nguyễn Văn Tiến  - 18521489

# %% [markdown]
# <h2><center>KHOÁ SỐ</center></h2>

# %% [markdown]
# ### Đề bài
#
# ----

# %% [markdown]
# <p style="text-align:justify">Để tăng độ an toàn chống hiện tượng cướp ngân hàng ngày càng phổ biến người ta dùng khóa số với mã mở khóa đơn giản nhưng rất hiệu quả. Trên cửa ra vào hiển thị một xâu khá dài các ký tự số. Các chữ số có thể di chuyển đổi chổ cho nhau hoặc bị xóa. Muốn mở khóa người ta phải di chuyển các chữ số và trong trường hợp cần thiết – xóa vài chữ số để nhận được <em>xâu lớn nhất</em> thỏa mãn điều kiện đã cài đặt. Điều kiện này được thay đổi thường xuyên. Hôm nay điều kiện đó là “Số nhận được phải chia hết cho 3”. Số nhận được có thể bắt đầu bằng các chữ số 0. Xâu “000” sẽ lớn hơn xâu “00”.</p>
#
# <p style="text-align:justify">Hãy xác định khóa mở cửa.</p>
#
# <p style="text-align:justify"><strong><em><span style="color:black">Dữ liệu:</span></em></strong> Vào từ thiết bị nhập chuẩn gồm một xâu ký tự số có độ dài lớn hơn 2 và không vượt quá 10<sup>5</sup>.</p>
#
# <p style="text-align:justify"><strong><em><span style="color:black">Kết quả:</span></em></strong> Đưa ra thiết bị xuất chuẩn xâu khóa mở cửa<span style="color:black">.</span></p>
#
# <p style="text-align:justify"><strong><em><span style="color:black">Ví dụ:</span></em></strong></p>
#
# <table border="1" cellspacing="0">
# 	<tbody>
# 		<tr>
# 			<td style="background-color:#ffffcc; width:63.0pt">
# 			<p style="text-align:justify"><tt><span style="color:black">INPUT</span></tt></p>
# 			</td>
# 			<td style="vertical-align:top; width:58.5pt">
# 			<p style="text-align:justify">&nbsp;</p>
# 			</td>
# 			<td style="background-color:#ffffcc; width:67.5pt">
# 			<p style="text-align:justify"><tt><span style="color:black">OUTPUT</span></tt></p>
# 			</td>
# 		</tr>
# 		<tr>
# 			<td style="background-color:#ffffcc; width:63.0pt">
# 			<p style="text-align:justify"><tt><strong><span style="color:black">105</span></strong></tt></p>
# 			</td>
# 			<td style="vertical-align:top; width:58.5pt">
# 			<p style="text-align:justify">&nbsp;</p>
# 			</td>
# 			<td style="background-color:#ffffcc; width:67.5pt">
# 			<p style="text-align:justify"><tt><strong><span style="color:black">510</span></strong></tt></p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %% [markdown]
# ### Tóm tắt bài toán
# -----

# %% [markdown]
# - Từ 1 số nguyên ban đầu, ta thực hiện các bước hoán đối vị trí các chữ số hoặc xóa đi các chữ số sao cho số nhận được là số lớn nhất và chia hết cho 3
#
# - Ví dụ:
#
#    Input:
#
#    1052
#
#    Output:
#
#    510
#
# - Ta thực hiện xóa số 2 để có thể nhận được số lớn nhất và chia hết cho 3 là số 510

# %% [markdown]
# ### Nhận diện khuôn mẫu
# ----

# %% [markdown]
# #### Số chia hết cho 3

# %% [markdown]
# Theo định lý toán học, số chia hết cho 3 có tổng các chữ số chia hết cho 3
#
# Ví dụ: các số như 3, 6, 9, 12, 15, 18, 21, ...

# %% [markdown]
# #### Kết luận

# %% [markdown]
# Tìm các số nhỏ nhất và số lượng các số đó ít nhất có thể sao cho loại bỏ các số đó ta nhận được tổng các chữ số còn lại chia hết cho 3

# %% [markdown]
# ### Thiết kế thuật toán
# ---

# %% [markdown]
# #### Input and Output

# %% [markdown]
# - Input:
#   Số nguyên n có độ dài chữ số lớn hơn 2 và không quá $10^5$.
# - Output:
#   In ra số lớn nhất và chia hết cho 3

# %% [markdown]
# #### Mã giả

# %%
### This is the pseudocode of Khoa So problem
#Input
Input the number n with data type is string because this length is very enormous
#Init
Init the array digit to count the quantity of number which appears in input

Count the quantity of numbers
Calculate the sum of numbers
If tong mod 3 == 0:
   Print the input
   Exit program
EndIf

If tong mod 3 equals by 1:
   Find a minimum number in input that modulo 3 equals by 1
   If a minimum number exists:
     Delete this minimum number
     Print result
     Exit program
   EndIf
   
   Find two minimum number in input that modulo 3 equals by 2
   Delete those numbers
   Print result
EndIf

If tong mod 3 equals by 2
   Find a minimum number in input that modulo 3 equals by 2
   If a minimum number exists:
     Delete this minimum number
     Print result
     Exit program
   EndIf
   
   Find two minimum number in input that modulo 3 equals by 1
   Delete those numbers
   Print result
EndIf

# %% [markdown]
# ### Cài đặt thuật toán

# %%
#Input
n = input()
#Init
digit=[0]*100
for i in range(len(n)):
    digit[ord(n[i])-48]+=1
tong=sum([(i*digit[i]) for i in range(10)])
#Optimize
if tong%3!=0:
    start=tong%3
    if tong%3 == 1:
        end=3
        step=1
    else:
        if tong%3==2:
            end=0
            step=-1
    for modnum in range(start,end,step):
        if tong%3==0:
            break
        so=modnum
        while so<10:
            while digit[so]>0 and tong%3!=0:
                digit[so]-=1
                tong-=so
            if tong%3==0:
                break
            so+=3
##Output
kq=''
for i in range(9,-1,-1):
    for j in range(digit[i]):
        kq+=chr(i+48)
print(kq)
# Out:
# 22222
# 222

# %% [markdown]
# ### Đánh giá thuật toán

# %% [markdown]
# The complexity of this algorithm: $O(len(n))$

# %% [markdown]
# ### Submit Wecode

# %% [markdown]
# ![image.png](data:image/png;base64,...)
